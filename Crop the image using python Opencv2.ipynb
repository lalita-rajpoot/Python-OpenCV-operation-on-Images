# %% [markdown]
# import packages

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# load sample image

# %%
pic = cv2.imread(r'C:\Users\This Pc\Desktop\ArthC\Opencv\together.jpg')

# %% [markdown]
# display loaded image

# %%
plt.title('Orignal')
plt.imshow(pic)

# %% [markdown]
# crop the image

# %%
crop_image = pic[0:200, 0:250]

# %% [markdown]
# display the cropped image

# %%
plt.title('Crop')
plt.imshow(crop_image)

# %% [markdown]
# load another sample image

# %%
pic2 = cv2.imread(r'C:\Users\This Pc\Desktop\ArthC\Opencv\nature.jpg')

# %% [markdown]
# display another loaded image

# %%
plt.title('Orignal')
plt.imshow(pic2)

# %% [markdown]
# crop 2nd sample image

# %%
crop2 = pic2[0:200, 0:250]

# %%
plt.title('cropped')
plt.imshow(crop2)

# %%
merge = np.vstack((crop_image, crop2))

# %%
plt.imshow(merge)
