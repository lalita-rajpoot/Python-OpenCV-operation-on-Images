# %% [markdown]
# import packages

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# load iamges

# %%
img= cv2.imread(r'C:\Users\This Pc\Desktop\ArthC\Opencv\sample.jpeg')

# %%
plt.title('sample image')
plt.imshow(img)

# %%
img1 = cv2.imread(r'C:\Users\This Pc\Desktop\ArthC\Opencv\sample1.jpeg')

# %%
plt.title('other sample image')
plt.imshow(img1)

# %%
img.shape
# Out:
# (1280, 720, 3)

# %%
img1.shape
# Out:
# (1280, 720, 3)

# %%
concat = np.hstack((img1, img))

# %%
plt.imshow(concat)

# %%
#successfully merged both the images in a single image
